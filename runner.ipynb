# %%
from analysis import *
from preprocess import *
from utils import *
import pandas as pd

# df = pd.read_csv('./test_datasets/Popular_Spotify_Songs.csv', encoding='ISO-8859-1')

# my_transform = default_transformer(size=(512, 512))
# images, file_lists, metadata = load_imageset('./test_datasets/Plants', transform=my_transform)

# %%
import random

a = []
b = []
c = []
mcnt = 0
ccnt = 0
for i in range(20):
    name = random.choice(['minsu', 'chulsu'])
    if name == 'minsu':
        a.append(mcnt)
        b.append(2 ** 2)
        c.append('minsu')
        mcnt += 1
    else:
        a.append(ccnt)
        b.append(3 ** 2)
        c.append('chulsu')
        ccnt += 1
    
df = pd.DataFrame({
    'a': a,
    'b': b,
    'c': c
})
print(df)

scatter(df, 'a', 'b')
regression(df, 'a', 'b', col='c')
# Out:
#      a  b       c
# 0    0  9  chulsu
# 1    0  4   minsu
# 2    1  9  chulsu
# 3    1  4   minsu
# 4    2  9  chulsu
# 5    2  4   minsu
# 6    3  9  chulsu
# 7    4  9  chulsu
# 8    5  9  chulsu
# 9    6  9  chulsu
# 10   7  9  chulsu
# 11   3  4   minsu
# 12   8  9  chulsu
# 13   9  9  chulsu
# 14   4  4   minsu
# 15   5  4   minsu
# 16  10  9  chulsu
# 17   6  4   minsu
# 18   7  4   minsu
# 19   8  4   minsu
