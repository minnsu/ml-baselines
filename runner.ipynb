# %%
from analysis import *
from preprocess import *
from utils import *
import pandas as pd

# df = pd.read_csv('./test_datasets/Popular_Spotify_Songs.csv', encoding='ISO-8859-1')

# my_transform = default_transformer(size=(512, 512))
# images, file_lists, metadata = load_imageset('./test_datasets/Plants', transform=my_transform)

# %%
import random

a = []
b = []
c = []
mcnt = 0
ccnt = 0
hcnt = 0
for i in range(20):
    name = random.choice(['minsu', 'chulsu', 'Heejin'])
    if name == 'minsu':
        a.append(mcnt)
        b.append(2 ** 2)
        c.append('minsu')
        mcnt += 1
    elif name=='chulsu':
        a.append(ccnt)
        b.append(3 ** 2)
        c.append('chulsu')
        ccnt += 1
    else:
        a.append(hcnt)
        b.append(4 ** 2)
        c.append('Heejin')
        hcnt += 1
    
df = pd.DataFrame({
    'a': a,
    'b': b,
    'c': c
})
print(df)

scatter(df, 'a', 'b')
regression(df, 'a', 'b', col='c')
# Out:
#     a   b       c
# 0   0   9  chulsu
# 1   1   9  chulsu
# 2   2   9  chulsu
# 3   0   4   minsu
# 4   0  16  Heejin
# 5   3   9  chulsu
# 6   4   9  chulsu
# 7   1  16  Heejin
# 8   5   9  chulsu
# 9   1   4   minsu
# 10  2  16  Heejin
# 11  2   4   minsu
# 12  3   4   minsu
# 13  4   4   minsu
# 14  3  16  Heejin
# 15  6   9  chulsu
# 16  5   4   minsu
# 17  6   4   minsu
# 18  4  16  Heejin
# 19  5  16  Heejin

# %%
# print(categorical_to_onehot(df, ['c']))
print(categorical_to_order(df, ['c']))
# Out:
#     a   b  c
# 0   0   9  1
# 1   1   9  1
# 2   2   9  1
# 3   0   4  2
# 4   0  16  0
# 5   3   9  1
# 6   4   9  1
# 7   1  16  0
# 8   5   9  1
# 9   1   4  2
# 10  2  16  0
# 11  2   4  2
# 12  3   4  2
# 13  4   4  2
# 14  3  16  0
# 15  6   9  1
# 16  5   4  2
# 17  6   4  2
# 18  4  16  0
# 19  5  16  0
